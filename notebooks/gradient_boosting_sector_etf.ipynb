# %% [markdown]
# # Sector ETF Outperformance Prediction - Gradient Boosting
#
# Implemented by **Jackson Wang**.
#
# This notebook documents the Gradient Boosting portion of the project. The full reproducible code is organized in `src/build_panel.py` and `src/gradient_boosting_model.py`.

# %% [markdown]
# ## Objective
#
# Predict whether a sector ETF will outperform SPY in the following month using momentum, volatility, drawdown, macro/rate, VIX, and ETF identity features.

# %%
# Run from the repository root after placing FRED CSV files in data/
# %run ../src/build_panel.py
# %run ../src/gradient_boosting_model.py

# %% [markdown]
# ## Selected Gradient Boosting hyperparameters
#
# - `n_estimators`: 50
# - `learning_rate`: 0.03
# - `max_depth`: 1
# - `min_samples_leaf`: 50
# - `subsample`: 0.8

# %% [markdown]
# ## Final performance
#
# | Dataset | Accuracy | Precision | Recall | F1 | ROC-AUC |
# |---|---:|---:|---:|---:|---:|
# | Train | 0.5702 | 0.5824 | 0.1970 | 0.2944 | 0.6511 |
# | Validation | 0.4458 | 0.4375 | 0.1654 | 0.2400 | 0.4716 |
# | Test | 0.5429 | 0.3818 | 0.1429 | 0.2079 | 0.5033 |
